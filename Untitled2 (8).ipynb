# %%
Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
you have collected data on the amount of time students spend studying for an exam and their final exam
scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.
Answer--To calculate the Pearson correlation coefficient between the amount of time students spend studying 
for an exam and their final exam scores, you need to have data pairs for both variables for each student. 
Once you have the data pairs, you can use the Pearson correlation formula.
Here's how to interpret the result:

If 
�
=
1
r=1, it indicates a perfect positive linear relationship between the two variables. As the amount of
time spent studying increases, the final exam scores also increase linearly.
If 
�
=
−
1
r=−1, it indicates a perfect negative linear relationship between the two variables. As the amount 
of time spent studying increases, the final exam scores decrease linearly.
If 
�
=
0
r=0, it indicates no linear relationship between the two variables.

Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
Suppose you have collected data on the amount of sleep individuals get each night and their overall job
satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
variables and interpret the result.
Answer--Spearman's rank correlation coefficient, denoted by 
�
ρ (rho), is a non-parametric measure of the strength and direction of association between 
two ranked variables. It assesses the monotonic relationship between variables, which means it 
captures whether one variable tends to increase or decrease as the other variable increases.

To calculate Spearman's rank correlation coefficient, follow these steps:

Rank the data for each variable separately. Assign ranks from 1 to 
�
n, where 
�
n is the number of observations. If there are ties, assign the average rank to tied values.
Calculate the difference between the ranks for each pair of observations.
Square the differences and calculate the sum of squared differences for each pair.
Use the formula to compute Spearman's rank correlation coefficient:
where:

�
ρ is the Spearman's rank correlation coefficient.
�
d is the difference in ranks between paired observations.
�
n is the number of observations.
Interpretation of the result:

If 
�
=
1
ρ=1, it indicates a perfect monotonic increasing relationship between the two variables.
As one variable increases, the other variable always increases.
If 
�
=
−
1
ρ=−1, it indicates a perfect monotonic decreasing relationship between the two variables.
As one variable increases, the other variable always decreases.
If 
�
=
0
ρ=0, it indicates no monotonic relationship between the two variables.
The value of 
�
ρ ranges between -1 and 1:

Closer to 1: Strong positive monotonic relationship
Closer to -1: Strong negative monotonic relationship
Closer to 0: Weak or no monotonic relationship

Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
between these two variables and compare the results.
Answer--import numpy as np
from scipy.stats import pearsonr, spearmanr

# Sample data (for demonstration purposes)
exercise_hours = [5, 3, 4, 6, 2, ...]  # Number of hours of exercise per week
bmi = [24, 26, 22, 28, 30, ...]          # Body mass index (BMI)

# Calculate Pearson correlation coefficient
pearson_corr, _ = pearsonr(exercise_hours, bmi)

# Calculate Spearman's rank correlation coefficient
spearman_corr, _ = spearmanr(exercise_hours, bmi)

print("Pearson correlation coefficient:", pearson_corr)
print("Spearman's rank correlation coefficient:", spearman_corr)

Q4. A researcher is interested in examining the relationship between the number of hours individuals
spend watching television per day and their level of physical activity. The researcher collected data on
both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
these two variables.
Answer--
